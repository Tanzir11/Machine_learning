# %% [markdown]
# Data are of 2 type:
# * Numerical Data: Height, age and etc.
# * Categorical Data: Country, Collage and etc

# %%
import pandas as pd

# %%
df = pd.read_csv('Titanic-Dataset.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # 1. Categorical Data

# %% [markdown]
# ## Countplot

# %%
import seaborn as sns

# %% [markdown]
# ### Monitoring the survival of people

# %%
sns.countplot(x = 'Survived', data=df)
df['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %% [markdown]
# Alternative way of plotting the same graph.
# * find the value count for each category and plot that on bar kind of graph

# %%
df['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
df['Survived'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Survived'>

# %% [markdown]
# ### Monitoring the devision of people in terms of class

# %%
sns.countplot(x='Pclass', data = df)
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
df['Pclass'].value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %% [markdown]
# Alternative way of plotting the same graph.
# * find the value count for each category and plot that on bar kind of graph

# %%
df['Pclass'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Pclass'>

# %% [markdown]
# ### Monitoring the sex of people on board

# %%
sns.countplot(x='Sex', data=df)
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %% [markdown]
# ### Monitoring where exactly people has embarked from

# %%
sns.countplot(x='Embarked', data=df)
# Out:
# <Axes: xlabel='Embarked', ylabel='count'>

# %% [markdown]
# ## Piechart

# %%
df['Survived'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# We can get the same information in terms of percentage and to get that we will be using pie chart

# %%
df['Survived'].value_counts().plot(kind='pie', autopct='%.2f')
# Out:
# <Axes: ylabel='count'>

# %%
df['Pclass'].value_counts().plot(kind='pie', autopct='%.2f')
# Out:
# <Axes: ylabel='count'>

# %%
df['Sex'].value_counts().plot(kind='pie', autopct='%.2f')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# # Numerical Data

# %% [markdown]
# ## Histogram

# %% [markdown]
# * We can make numerical data behave like a categorical data using histogram by creating bins.
# * let's say the minimum age on board of the passenger is 0 and the maximum is 80 we can create 8 bins that will range from 0-10, 10,-20 and so on.

# %%
import matplotlib.pyplot as plt
plt.hist(df['Age'],bins=15)
# Out:
# (array([ 44.,  24.,  32., 104., 115., 127.,  80.,  59.,  49.,  30.,  22.,
#          17.,   4.,   6.,   1.]),
#  array([ 0.42      ,  5.72533333, 11.03066667, 16.336     , 21.64133333,
#         26.94666667, 32.252     , 37.55733333, 42.86266667, 48.168     ,
#         53.47333333, 58.77866667, 64.084     , 69.38933333, 74.69466667,
#         80.        ]),
#  <BarContainer object of 15 artists>)

# %% [markdown]
# ## Distplot

# %% [markdown]
# This gives us PDF i.e probability density function

# %% [markdown]
# We can get the skewness with this plot

# %%
sns.distplot(df['Age'],bins=30)
# Out:
# C:\Users\tanze\AppData\Local\Temp\ipykernel_21444\3776805194.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'],bins=30)
# <Axes: xlabel='Age', ylabel='Density'>

# %% [markdown]
# ## Boxplot

# %% [markdown]
# this gives us 5 number summary:
# * Median (50 percentile)
# * Percentile value (*Q1 = 25th percentile value and *Q3 = 75th percentile value)
# * Inter Quartile Range(IQR) are values in between Q1 and Q3
# * *Minimum is calculated by (Q1-1.5*IQR)
# * *Maximum is calculated by (Q3+1.5*IQR)

# %%
sns.boxplot(x='Age', data=df)
# Out:
# <Axes: xlabel='Age'>

# %%
df['Age'].min()
# Out:
# 0.42

# %%
df['Age'].max()
# Out:
# 80.0

# %%
# Free loader
df['Fare'].min()
# Out:
# 0.0

# %%
# Thag lia isko
df['Fare'].max()
# Out:
# 512.3292

# %% [markdown]
# #### Calculating skewness

# %%
df['Age'].skew()
# Out:
# 0.38910778230082704

# %%
df['Fare'].skew()
# Out:
# 4.787316519674893
